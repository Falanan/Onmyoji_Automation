# %% [markdown]
# # This notebook ONLY tested on windows operation system
# #### Not sure if worked on macOS

# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %% [markdown]
# ### pyautogui
# - worked fine on Windows

# %%
import pyautogui

# %%
img_pyautogui = pyautogui.screenshot()
# img_pyautogui = cv.cvtColor(np.asarray(img_pyautogui),cv.COLOR_RGB2BGR)
img_pyautogui = np.asanyarray(img_pyautogui)
plt.imshow(img_pyautogui)
print(img_pyautogui.shape)
# Out:
# (1080, 1920, 3)

# %% [markdown]
# ### Win32 API

# %%
# from PyQt5.QtWidgets import QApplication
import win32gui
import sys

hwnd_title = dict() #创建字典保存窗口的句柄与名称映射关系


def get_all_hwnd(hwnd, mouse):
    if win32gui.IsWindow(hwnd) and win32gui.IsWindowEnabled(hwnd) and win32gui.IsWindowVisible(hwnd):
        hwnd_title.update({hwnd: win32gui.GetWindowText(hwnd)})

win32gui.EnumWindows(get_all_hwnd, 0)

for h, t in hwnd_title.items():
    if t!= "":
        print(h, t)
# Out:
# 66744 ● get_screen_shot.ipynb - Onmyoji_Automation - Visual Studio Code
# 1248102 (必备技能)使用Python实现屏幕截图_普通网友的博客-CSDN博客_python获取屏幕截图 和另外 8 个页面 - 个人 - Microsoft​ Edge
# 132544 任务管理器
# 328614 本地磁盘 (C:)
# 264156 设置
# 131580 设置
# 132834 安装
# 197374 Microsoft Text Input Application
# 1509780 GitHub Desktop
# 854334 C:\Windows\system32\cmd.exe
# 657896 Anaconda Navigator
# 198556 requirements.txt - 记事本
# 65898 Program Manager

# %%
bbox = win32gui.GetWindowRect(132544)
print(bbox)
# b = [634, 42, 1590, 872]
b = [634, 42, 1590-634, 872-42]
# b = [0,0,100,100]
# Out:
# (634, 42, 1590, 872)

# %%
test_region_sc = pyautogui.screenshot(region=b)
test_region_sc = np.asarray(test_region_sc)
plt.imshow(test_region_sc)

# %%
# #这个是截取全屏的
# hwnd = win32gui.FindWindow(None, 'C:/Windows/system32/cmd.exe')
# app = QApplication(sys.argv)
# screen = QApplication.primaryScreen()
# img = screen.grabWindow(hwnd).toImage()
# # plt.imshow(img.size)
# print(img)
