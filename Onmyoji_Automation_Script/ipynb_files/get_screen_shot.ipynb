# %% [markdown]
# # This notebook ONLY tested on windows operation system
# #### Not sure if worked on macOS

# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np

# %% [markdown]
# ### pyautogui
# - worked fine on Windows

# %%
import pyautogui

# %%
img_pyautogui = pyautogui.screenshot()
# img_pyautogui = cv.cvtColor(np.asarray(img_pyautogui),cv.COLOR_RGB2BGR)
img_pyautogui = np.asanyarray(img_pyautogui)
plt.imshow(img_pyautogui)
print(img_pyautogui.shape)
# Out:
# (1080, 1920, 3)

# %% [markdown]
# ### Win32 API

# %%
# from PyQt5.QtWidgets import QApplication
import win32gui
# import sys

hwnd_title = dict() # Save thread name and window name


def get_all_hwnd(hwnd, mouse):
    if win32gui.IsWindow(hwnd) and win32gui.IsWindowEnabled(hwnd) and win32gui.IsWindowVisible(hwnd):
        hwnd_title.update({hwnd: win32gui.GetWindowText(hwnd)})

win32gui.EnumWindows(get_all_hwnd, 0)

for h, t in hwnd_title.items():
    if t!= "":
        print(h, t)
# Out:
# 66748 ● get_screen_shot.ipynb - Onmyoji_Automation - Visual Studio Code
# 395254 How to Control your Mouse in Python - Python Code 和另外 2 个页面 - 用户配置 1 - Microsoft​ Edge
# 920124 NemuPlayer
# 1051144 阴阳师 - MuMu模拟器
# 198446 NemuPlayer
# 329974 #N1 阴阳师 - MuMu模拟器
# 329496 任务管理器
# 198170 设置
# 131336 设置
# 131542 Microsoft Text Input Application
# 262668 GitHub Desktop
# 264732 MuMu模拟器
# 65916 Program Manager

# %%
bbox = win32gui.GetWindowRect(329974)
bbox = list(bbox)
bbox[2] = bbox[2] - bbox[0]
bbox[3] = bbox[3] - bbox[1]
print(bbox)
# b = [634, 42, 1590, 872]
# bbox = [634, 42, 1590-634, 872-42]
# b = [0,0,100,100]
# Out:
# [986, 10, 769, 520]

# %%
test_region_sc = pyautogui.screenshot(region=bbox)
test_region_sc = np.asarray(test_region_sc)
plt.imshow(test_region_sc)

# %%
test_region_sc = cv.cvtColor(test_region_sc, cv.COLOR_RGB2BGR)

cv.imwrite("pics/testw.jpg", test_region_sc)
# Out:
# True

# %%
# #这个是截取全屏的
# hwnd = win32gui.FindWindow(None, 'C:/Windows/system32/cmd.exe')
# app = QApplication(sys.argv)
# screen = QApplication.primaryScreen()
# img = screen.grabWindow(hwnd).toImage()
# # plt.imshow(img.size)
# print(img)
