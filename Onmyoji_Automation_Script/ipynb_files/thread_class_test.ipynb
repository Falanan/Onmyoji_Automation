# %%
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import pyautogui
import threading
import time

# %%
img_pyautogui = pyautogui.screenshot()
# img_pyautogui = cv.cvtColor(np.asarray(img_pyautogui),cv.COLOR_RGB2BGR)
img_pyautogui = np.asanyarray(img_pyautogui)
plt.imshow(img_pyautogui)
print(img_pyautogui.shape)
# Out:
# (1964, 3024, 4)

# %%
screenshots_list = []

# %%
class getScreenShotThread(threading.Thread):
    global screenshots_list

    def run(self):
        # global screenshots_list
        while True:
            img_pyautogui = pyautogui.screenshot()
            # img_pyautogui = cv.cvtColor(np.asarray(img_pyautogui),cv.COLOR_RGB2BGR)
            # img_pyautogui = np.asanyarray(img_pyautogui)
            screenshots_list.append(img_pyautogui)
            time.sleep(5)

# %%
t = getScreenShotThread()
t.start()

# %%
while True:
    fig, axs = plt.subplots(1, len(screenshots_list), figsize=(15,5))
    for idx, ax in enumerate(axs):
        # ax.set_xticks([])
        # ax.set_yticks([])
        ax.imshow(screenshots_list[idx],cmap="gray")
    time.sleep(4)
    # print(len(screenshots_list))
    # time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qt/0w09tyxs2rd6p1ssxw6f889w0000gn/T/ipykernel_42416/21745881.py in <module>
#       5         # ax.set_yticks([])
#       6         ax.imshow(screenshots_list[idx],cmap="gray")
# ----> 7     time.sleep(4)
#       8     # print(len(screenshots_list))
#       9     # time.sleep(3)
#
# KeyboardInterrupt:

# %%
exit(0)

# %%
print(len(screenshots_list))
